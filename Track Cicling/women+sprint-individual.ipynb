# %%
import json
import numpy as np
#from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sprint_individual_tournament import Cyclist, Tournament
from functools import partial
# %matplotlib inline

# %%
data = json.load(open('./data/women_sprint.json',encoding="utf-8"))
del data['Bronze medal final']
del data['Bronze medal race']
del data['Gold medal final']
del data['Gold medal race']

# %%
gaps = []
behinds = []
ciclysts = {}
times = []
for name,info in data.items():
    ciclysts[name]={
        'name': name,
        'nation': None,
        'years': [],
        'qualifying': {
            'times': [],
            'behinds': []
        },
        'rounds': {
            'gaps': []
        }
    }
    for year,yinfo in sorted(info.items(), key=lambda x: x[0]):
        ciclysts[name]['years'].append(int(year))
        for rinfo in yinfo.values():
            if ciclysts[name]['nation'] is None:
                ciclysts[name]['nation'] = rinfo['Nation']
            if rinfo.get('Gap',None):
                try:
                    gap = float(rinfo.get('Gap'))
                    gaps.append(gap)
                    ciclysts[name]['rounds']['gaps'].append(gap)
                except ValueError:
                    if rinfo.get('Gap')=="X":
                        ciclysts[name]['rounds']['gaps'].append(0)

                if rinfo.get('Race 1'):
                    try:
                        gap = float(rinfo.get('Race 1'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 1')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)

                    try:
                        gap = float(rinfo.get('Race 2'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 2')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)
            else:
                if rinfo.get('Behind',None):
                    try:
                        behind = float(rinfo.get('Behind'))
                        behinds.append(behind)
                        ciclysts[name]['qualifying']['behinds'].append(behind)
                    except ValueError:
                        pass
                if rinfo.get('Time',None):
                    try:
                        time = float(rinfo.get('Time'))
                        times.append(time)
                        ciclysts[name]['qualifying']['times'].append(time)
                    except ValueError:
                        pass

# %%
gaps_m = np.array(list(sorted(gaps))).mean()
behinds_m = np.array(list(sorted(behinds))).mean()
times_m = np.array(list(sorted(times))).mean()

# %%
for name in ciclysts.keys():
    mu = np.array(ciclysts[name]['qualifying']['times']).mean()
    if len(ciclysts[name]['qualifying']['times'])==1:
        variance =(behinds_m +np.array(ciclysts[name]['qualifying']['behinds']).mean())/2
    else:
        variance = np.abs(np.diff(np.array(ciclysts[name]['qualifying']['times']))).mean()
    sigma = math.sqrt(variance)
    ciclysts[name]['qualifying']['mean']=mu
    ciclysts[name]['qualifying']['std']=sigma

    mu = times_m
    if len(ciclysts[name]['rounds']['gaps'])==0:
        variance = 3/2*gaps_m
    else:
        variance = np.array(ciclysts[name]['rounds']['gaps']).mean()
        if len(ciclysts[name]['rounds']['gaps'])==1:
            variance = (4/3*gaps_m + variance)/2

    sigma = math.sqrt(variance)
    ciclysts[name]['rounds']['mean']=mu
    ciclysts[name]['rounds']['std']=sigma

# %%
# generate cyclist time function asumming normal distribution
cyclists_i = []
for i in ciclysts.values():
    qualify_time_function = partial(stats.norm.rvs,i['qualifying']['mean'],i['qualifying']['std'])
    round_time_fuction = partial(stats.norm.rvs,i['rounds']['mean'],i['rounds']['std'])
    name = i['name']
    nation = i['nation']
    cyclist = Cyclist(qualify_time_function, round_time_fuction, name, nation)
    cyclists_i.append(cyclist)

# %%
tournament = Tournament(cyclists_i)

# %%
results = {i.name:[] for i in cyclists_i}
nit = 10000

# %%
# run nit tournaments and save results
for i in range(nit):
    tournament.run()
    res = list(map(lambda x: x.name,tournament.winners))
    tournament.reset()
    for n,name in enumerate(res):
        results[name].append(n)

# %%
nations = {i.name:i.nation for i in cyclists_i}

# %%
confidences = {}

for name, places in results.items():
    mean = np.mean(places)
    interval = stats.t.interval(0.95, len(places)-1, loc=mean, scale=stats.sem(places))
    confidences[name]= {
        'mean':mean,
        'interval': interval,
        'gap': mean-interval[0]
    }

# %%
sorted_cyclists = list(sorted(confidences.items(),key=lambda x: x[1]['mean']))

# %%
fix_results = {}
min_rank = math.floor(sorted_cyclists[0][1]['mean'])
for n,(name, data) in enumerate(sorted_cyclists):
    rank = int(math.floor(data['mean'])-min_rank) + 1
    fix_results[name] = {
        'rank': rank,
        'gap': data['gap'],
        'sorted_rank': n,
        'nation': nations[name] 
    }

# %%
fix_results
# Out:
# {'Kristina Vogel': {'rank': 1,
#   'gap': 0.16551422440075747,
#   'sorted_rank': 0,
#   'nation': 'Germany'},
#  'Stephanie Morton': {'rank': 1,
#   'gap': 0.17996526240619737,
#   'sorted_rank': 1,
#   'nation': 'Australia'},
#  'Kelsey Mitchell': {'rank': 3,
#   'gap': 0.2381556261329898,
#   'sorted_rank': 2,
#   'nation': 'Canada'},
#  'Lea Friedrich': {'rank': 4,
#   'gap': 0.24206736145070096,
#   'sorted_rank': 3,
#   'nation': 'Germany'},
#  'Miriam Vece': {'rank': 5,
#   'gap': 0.26040164640039976,
#   'sorted_rank': 4,
#   'nation': 'Italy'},
#  'Zhong Tianshi': {'rank': 5,
#   'gap': 0.2622233359524877,
#   'sorted_rank': 5,
#   'nation': 'China'},
#  'Lee Wai Sze': {'rank': 5,
#   'gap': 0.24908154712621666,
#   'sorted_rank': 6,
#   'nation': 'Hong Kong'},
#  'Sophie Capewell': {'rank': 6,
#   'gap': 0.272193036867332,
#   'sorted_rank': 7,
#   'nation': 'Great Britain'},
#  'Mathilde Gros': {'rank': 6,
#   'gap': 0.24513197220700533,
#   'sorted_rank': 8,
#   'nation': 'France'},
#  'Kaarle McCulloch': {'rank': 6,
#   'gap': 0.23989016240537353,
#   'sorted_rank': 9,
#   'nation': 'Australia'},
#  'Daria Shmeleva': {'rank': 8,
#   'gap': 0.24882670745715174,
#   'sorted_rank': 10,
#   'nation': 'Russia'},
#  'Lauriane Genest': {'rank': 8,
#   'gap': 0.29337760056162665,
#   'sorted_rank': 11,
#   'nation': 'Canada'},
#  'Simona Krupeckaitė': {'rank': 8,
#   'gap': 0.24032231866592113,
#   'sorted_rank': 12,
#   'nation': 'Lithuania'},
#  'Jessica Salazar': {'rank': 9,
#   'gap': 0.30192743664460764,
#   'sorted_rank': 13,
#   'nation': 'Mexico'},
#  'Pauline Grabosch': {'rank': 9,
#   'gap': 0.2843330878617607,
#   'sorted_rank': 14,
#   'nation': 'Germany'},
#  'Anastasia Voynova': {'rank': 9,
#   'gap': 0.26704736823604946,
#   'sorted_rank': 15,
#   'nation': 'Russia'},
#  'Emma Hinze': {'rank': 10,
#   'gap': 0.3054931624690269,
#   'sorted_rank': 16,
#   'nation': 'Germany'},
#  'Natasha Hansen': {'rank': 10,
#   'gap': 0.2739354295848919,
#   'sorted_rank': 17,
#   'nation': 'New Zealand'},
#  'Laurine van Riessen': {'rank': 10,
#   'gap': 0.2859209742217139,
#   'sorted_rank': 18,
#   'nation': 'Netherlands'},
#  'Katy Marchant': {'rank': 11,
#   'gap': 0.2824267914823544,
#   'sorted_rank': 19,
#   'nation': 'Great Britain'},
#  'Shanne Braspennincx': {'rank': 11,
#   'gap': 0.30312650101708627,
#   'sorted_rank': 20,
#   'nation': 'Netherlands'},
#  'Olena Starikova': {'rank': 12,
#   'gap': 0.2988511351384098,
#   'sorted_rank': 21,
#   'nation': 'Ukraine'},
#  'Jessica Lee Hoi Yan': {'rank': 12,
#   'gap': 0.24351410172421595,
#   'sorted_rank': 22,
#   'nation': 'Hong Kong'},
#  'Sarah Orban': {'rank': 13,
#   'gap': 0.33288345822382936,
#   'sorted_rank': 23,
#   'nation': 'Canada'},
#  'Riyu Ohta': {'rank': 13,
#   'gap': 0.32766302638450995,
#   'sorted_rank': 24,
#   'nation': 'Japan'},
#  'Olivia Podmore': {'rank': 13,
#   'gap': 0.31655387899997933,
#   'sorted_rank': 25,
#   'nation': 'New Zealand'},
#  'Daniela Gaxiola': {'rank': 13,
#   'gap': 0.32064917089988043,
#   'sorted_rank': 26,
#   'nation': 'Mexico'},
#  'Miriam Welte': {'rank': 14,
#   'gap': 0.32392215491064036,
#   'sorted_rank': 27,
#   'nation': 'Germany'},
#  'Miglė Marozaitė': {'rank': 14,
#   'gap': 0.2567331800669912,
#   'sorted_rank': 28,
#   'nation': 'Lithuania'},
#  'Madalyn Godby': {'rank': 14,
#   'gap': 0.29212089719614553,
#   'sorted_rank': 29,
#   'nation': 'United States'},
#  'Yuka Kobayashi': {'rank': 15,
#   'gap': 0.3101393752621959,
#   'sorted_rank': 30,
#   'nation': 'Japan'},
#  'Martha Bayona': {'rank': 16,
#   'gap': 0.2924760966724804,
#   'sorted_rank': 31,
#   'nation': 'Colombia'},
#  'Ekaterina Rogovaya': {'rank': 16,
#   'gap': 0.34329228934294775,
#   'sorted_rank': 32,
#   'nation': 'Russia'},
#  'Holly Takos': {'rank': 16,
#   'gap': 0.3274116640352709,
#   'sorted_rank': 33,
#   'nation': 'Australia'},
#  'Hetty van de Wouw': {'rank': 16,
#   'gap': 0.34018679931517326,
#   'sorted_rank': 34,
#   'nation': 'Netherlands'},
#  "Kate O'Brien": {'rank': 16,
#   'gap': 0.33219947847307907,
#   'sorted_rank': 35,
#   'nation': 'Canada'},
#  'Tania Calvo': {'rank': 17,
#   'gap': 0.2700922572779483,
#   'sorted_rank': 36,
#   'nation': 'Spain'},
#  'Lin Junhong': {'rank': 17,
#   'gap': 0.24626771535329084,
#   'sorted_rank': 37,
#   'nation': 'China'},
#  'Lyubov Basova': {'rank': 18,
#   'gap': 0.2720390337406968,
#   'sorted_rank': 38,
#   'nation': 'Ukraine'},
#  'Lee Hye-jin': {'rank': 19,
#   'gap': 0.22075564557992422,
#   'sorted_rank': 39,
#   'nation': 'South Korea'},
#  'Mandy Marquardt': {'rank': 19,
#   'gap': 0.3091780794263812,
#   'sorted_rank': 40,
#   'nation': 'United States'},
#  'Nicky Degrendele': {'rank': 20,
#   'gap': 0.22680142553326732,
#   'sorted_rank': 41,
#   'nation': 'Belgium'},
#  'Natalia Antonova': {'rank': 20,
#   'gap': 0.34277575794148163,
#   'sorted_rank': 42,
#   'nation': 'Russia'},
#  'Emma Cumming': {'rank': 21,
#   'gap': 0.3385411318742655,
#   'sorted_rank': 43,
#   'nation': 'New Zealand'},
#  'Marlena Karwacka': {'rank': 22,
#   'gap': 0.3444011522057835,
#   'sorted_rank': 44,
#   'nation': 'Poland'},
#  'Amelia Walsh': {'rank': 22,
#   'gap': 0.3426436890530766,
#   'sorted_rank': 45,
#   'nation': 'Canada'},
#  'Charlene du Preez': {'rank': 23,
#   'gap': 0.3392899388326214,
#   'sorted_rank': 46,
#   'nation': 'South Africa'},
#  'Guo Yufang': {'rank': 23,
#   'gap': 0.3423335129597689,
#   'sorted_rank': 47,
#   'nation': 'China'},
#  'Kayono Maeda': {'rank': 24,
#   'gap': 0.34110630319923274,
#   'sorted_rank': 48,
#   'nation': 'Japan'},
#  'Julita Jagodzińska': {'rank': 24,
#   'gap': 0.3387969573320504,
#   'sorted_rank': 49,
#   'nation': 'Poland'},
#  'Yuli Verdugo': {'rank': 25,
#   'gap': 0.33649990521346496,
#   'sorted_rank': 50,
#   'nation': 'Mexico'},
#  'Kim Won-gyeong': {'rank': 26,
#   'gap': 0.3179961204871873,
#   'sorted_rank': 51,
#   'nation': 'South Korea'},
#  'Juliana Gaviria': {'rank': 26,
#   'gap': 0.33052489333690005,
#   'sorted_rank': 52,
#   'nation': 'Colombia'},
#  'Robyn Stewart': {'rank': 26,
#   'gap': 0.10809594163716696,
#   'sorted_rank': 53,
#   'nation': 'Ireland'},
#  'Li Yin Yin': {'rank': 27,
#   'gap': 0.33070794644917356,
#   'sorted_rank': 54,
#   'nation': 'Hong Kong'},
#  'Helena Casas': {'rank': 29,
#   'gap': 0.3135261927796833,
#   'sorted_rank': 55,
#   'nation': 'Spain'},
#  'Deborah Herold': {'rank': 30,
#   'gap': 0.3120285922164854,
#   'sorted_rank': 56,
#   'nation': 'India'},
#  'Ma Wing Yu': {'rank': 34,
#   'gap': 0.14332064106586984,
#   'sorted_rank': 57,
#   'nation': 'Hong Kong'}}

# %%
json.dump(fix_results,open('women_sprint_results.json','w'), indent=2)
