# %%
import json
import numpy as np
#from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sprint_individual_tournament import Cyclist, Tournament
from functools import partial
# %matplotlib inline

# %%
data = json.load(open('./data/women_sprint.json',encoding="utf-8"))
del data['Bronze medal final']
del data['Bronze medal race']
del data['Gold medal final']
del data['Gold medal race']

# %%
gaps = []
behinds = []
ciclysts = {}
times = []
for name,info in data.items():
    ciclysts[name]={
        'name': name,
        'nation': None,
        'years': [],
        'qualifying': {
            'times': [],
            'behinds': []
        },
        'rounds': {
            'gaps': []
        }
    }
    for year,yinfo in sorted(info.items(), key=lambda x: x[0]):
        ciclysts[name]['years'].append(int(year))
        for rinfo in yinfo.values():
            if ciclysts[name]['nation'] is None:
                ciclysts[name]['nation'] = rinfo['Nation']
            if rinfo.get('Gap',None):
                try:
                    gap = float(rinfo.get('Gap'))
                    gaps.append(gap)
                    ciclysts[name]['rounds']['gaps'].append(gap)
                except ValueError:
                    if rinfo.get('Gap')=="X":
                        ciclysts[name]['rounds']['gaps'].append(0)

                if rinfo.get('Race 1'):
                    try:
                        gap = float(rinfo.get('Race 1'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 1')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)

                    try:
                        gap = float(rinfo.get('Race 2'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 2')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)
            else:
                if rinfo.get('Behind',None):
                    try:
                        behind = float(rinfo.get('Behind'))
                        behinds.append(behind)
                        ciclysts[name]['qualifying']['behinds'].append(behind)
                    except ValueError:
                        pass
                if rinfo.get('Time',None):
                    try:
                        time = float(rinfo.get('Time'))
                        times.append(time)
                        ciclysts[name]['qualifying']['times'].append(time)
                    except ValueError:
                        pass

# %%
gaps_m = np.array(list(sorted(gaps))).mean()
behinds_m = np.array(list(sorted(behinds))).mean()
times_m = np.array(list(sorted(times))).mean()

# %%
for name in ciclysts.keys():
    mu = np.array(ciclysts[name]['qualifying']['times']).mean()
    if len(ciclysts[name]['qualifying']['times'])==1:
        variance =(behinds_m +np.array(ciclysts[name]['qualifying']['behinds']).mean())/2
    else:
        variance = np.abs(np.diff(np.array(ciclysts[name]['qualifying']['times']))).mean()
    sigma = math.sqrt(variance)
    ciclysts[name]['qualifying']['mean']=mu
    ciclysts[name]['qualifying']['std']=sigma

    mu = times_m
    if len(ciclysts[name]['rounds']['gaps'])==0:
        variance = 3/2*gaps_m
    else:
        variance = np.array(ciclysts[name]['rounds']['gaps']).mean()
        if len(ciclysts[name]['rounds']['gaps'])==1:
            variance = (4/3*gaps_m + variance)/2

    sigma = math.sqrt(variance)
    ciclysts[name]['rounds']['mean']=mu
    ciclysts[name]['rounds']['std']=sigma

# %%
# generate cyclist time function asumming normal distribution
cyclists_i = []
for i in ciclysts.values():
    qualify_time_function = partial(stats.norm.rvs,i['qualifying']['mean'],i['qualifying']['std'])
    round_time_fuction = partial(stats.norm.rvs,i['rounds']['mean'],i['rounds']['std'])
    name = i['name']
    nation = i['nation']
    cyclist = Cyclist(qualify_time_function, round_time_fuction, name, nation)
    cyclists_i.append(cyclist)

# %%
tournament = Tournament(cyclists_i)

# %%
results = {i.name:[] for i in cyclists_i}
nit = 10000

# %%
# run nit tournaments and save results
for i in range(nit):
    tournament.run()
    res = list(map(lambda x: x.name,tournament.winners))
    tournament.reset()
    for n,name in enumerate(res):
        results[name].append(n)

# %%
nations = {i.name:i.nation for i in cyclists_i}

# %%
confidences = {}

for name, places in results.items():
    mean = np.mean(places)
    interval = stats.t.interval(0.95, len(places)-1, loc=mean, scale=stats.sem(places))
    confidences[name]= {
        'mean':mean,
        'interval': interval,
        'gap': mean-interval[0]
    }

# %%
sorted_cyclists = list(sorted(confidences.items(),key=lambda x: x[1]['mean']))

# %%
fix_results = {}
min_rank = math.floor(sorted_cyclists[0][1]['mean'])
for n,(name, data) in enumerate(sorted_cyclists):
    rank = int(math.floor(data['mean'])-min_rank) + 1
    fix_results[name] = {
        'rank': rank,
        'gap': data['gap'],
        'sorted_rank': n,
        'nation': nations[name] 
    }

# %%
fix_results
# Out:
# {'Kristina Vogel': {'rank': 1,
#   'gap': 0.16709291494245093,
#   'sorted_rank': 0,
#   'nation': 'Germany'},
#  'Stephanie Morton': {'rank': 2,
#   'gap': 0.17890202583634185,
#   'sorted_rank': 1,
#   'nation': 'Australia'},
#  'Kelsey Mitchell': {'rank': 4,
#   'gap': 0.23990070038258082,
#   'sorted_rank': 2,
#   'nation': 'Canada'},
#  'Lea Friedrich': {'rank': 5,
#   'gap': 0.2434689416478406,
#   'sorted_rank': 3,
#   'nation': 'Germany'},
#  'Zhong Tianshi': {'rank': 6,
#   'gap': 0.26299495816395435,
#   'sorted_rank': 4,
#   'nation': 'China'},
#  'Miriam Vece': {'rank': 6,
#   'gap': 0.2614300402814038,
#   'sorted_rank': 5,
#   'nation': 'Italy'},
#  'Lee Wai Sze': {'rank': 6,
#   'gap': 0.24887848822851666,
#   'sorted_rank': 6,
#   'nation': 'Hong Kong'},
#  'Sophie Capewell': {'rank': 7,
#   'gap': 0.2749664837426984,
#   'sorted_rank': 7,
#   'nation': 'Great Britain'},
#  'Mathilde Gros': {'rank': 7,
#   'gap': 0.24537623518971685,
#   'sorted_rank': 8,
#   'nation': 'France'},
#  'Kaarle McCulloch': {'rank': 7,
#   'gap': 0.24008808306939144,
#   'sorted_rank': 9,
#   'nation': 'Australia'},
#  'Daria Shmeleva': {'rank': 9,
#   'gap': 0.25096766154807426,
#   'sorted_rank': 10,
#   'nation': 'Russia'},
#  'Lauriane Genest': {'rank': 9,
#   'gap': 0.29573048543711167,
#   'sorted_rank': 11,
#   'nation': 'Canada'},
#  'Simona Krupeckaitė': {'rank': 9,
#   'gap': 0.24010248306879234,
#   'sorted_rank': 12,
#   'nation': 'Lithuania'},
#  'Anastasia Voynova': {'rank': 10,
#   'gap': 0.2660106492697736,
#   'sorted_rank': 13,
#   'nation': 'Russia'},
#  'Jessica Salazar': {'rank': 10,
#   'gap': 0.3041092325805508,
#   'sorted_rank': 14,
#   'nation': 'Mexico'},
#  'Pauline Grabosch': {'rank': 10,
#   'gap': 0.28639566741298594,
#   'sorted_rank': 15,
#   'nation': 'Germany'},
#  'Emma Hinze': {'rank': 11,
#   'gap': 0.3065203688421896,
#   'sorted_rank': 16,
#   'nation': 'Germany'},
#  'Natasha Hansen': {'rank': 11,
#   'gap': 0.27512629310366066,
#   'sorted_rank': 17,
#   'nation': 'New Zealand'},
#  'Laurine van Riessen': {'rank': 12,
#   'gap': 0.28497291543290615,
#   'sorted_rank': 18,
#   'nation': 'Netherlands'},
#  'Katy Marchant': {'rank': 12,
#   'gap': 0.28088951404776097,
#   'sorted_rank': 19,
#   'nation': 'Great Britain'},
#  'Shanne Braspennincx': {'rank': 12,
#   'gap': 0.3064031070350417,
#   'sorted_rank': 20,
#   'nation': 'Netherlands'},
#  'Olena Starikova': {'rank': 13,
#   'gap': 0.2969693252199299,
#   'sorted_rank': 21,
#   'nation': 'Ukraine'},
#  'Riyu Ohta': {'rank': 13,
#   'gap': 0.3275438708407954,
#   'sorted_rank': 22,
#   'nation': 'Japan'},
#  'Jessica Lee Hoi Yan': {'rank': 13,
#   'gap': 0.24108418455321612,
#   'sorted_rank': 23,
#   'nation': 'Hong Kong'},
#  'Olivia Podmore': {'rank': 13,
#   'gap': 0.31767442714726,
#   'sorted_rank': 24,
#   'nation': 'New Zealand'},
#  'Sarah Orban': {'rank': 14,
#   'gap': 0.33059759941185973,
#   'sorted_rank': 25,
#   'nation': 'Canada'},
#  'Daniela Gaxiola': {'rank': 15,
#   'gap': 0.3212521452041379,
#   'sorted_rank': 26,
#   'nation': 'Mexico'},
#  'Miglė Marozaitė': {'rank': 15,
#   'gap': 0.2592394739436692,
#   'sorted_rank': 27,
#   'nation': 'Lithuania'},
#  'Yuka Kobayashi': {'rank': 15,
#   'gap': 0.30835662215602966,
#   'sorted_rank': 28,
#   'nation': 'Japan'},
#  'Miriam Welte': {'rank': 15,
#   'gap': 0.32366690011419763,
#   'sorted_rank': 29,
#   'nation': 'Germany'},
#  'Madalyn Godby': {'rank': 15,
#   'gap': 0.2912109462756334,
#   'sorted_rank': 30,
#   'nation': 'United States'},
#  'Ekaterina Rogovaya': {'rank': 16,
#   'gap': 0.3430197033979283,
#   'sorted_rank': 31,
#   'nation': 'Russia'},
#  'Holly Takos': {'rank': 17,
#   'gap': 0.3268407877479653,
#   'sorted_rank': 32,
#   'nation': 'Australia'},
#  'Martha Bayona': {'rank': 17,
#   'gap': 0.2921383644268545,
#   'sorted_rank': 33,
#   'nation': 'Colombia'},
#  "Kate O'Brien": {'rank': 17,
#   'gap': 0.33142637669132213,
#   'sorted_rank': 34,
#   'nation': 'Canada'},
#  'Hetty van de Wouw': {'rank': 17,
#   'gap': 0.33593341560249357,
#   'sorted_rank': 35,
#   'nation': 'Netherlands'},
#  'Tania Calvo': {'rank': 18,
#   'gap': 0.2692704939527282,
#   'sorted_rank': 36,
#   'nation': 'Spain'},
#  'Lin Junhong': {'rank': 18,
#   'gap': 0.24646893590737307,
#   'sorted_rank': 37,
#   'nation': 'China'},
#  'Lyubov Basova': {'rank': 19,
#   'gap': 0.2730329429237628,
#   'sorted_rank': 38,
#   'nation': 'Ukraine'},
#  'Lee Hye-jin': {'rank': 19,
#   'gap': 0.22148772268734263,
#   'sorted_rank': 39,
#   'nation': 'South Korea'},
#  'Mandy Marquardt': {'rank': 21,
#   'gap': 0.3048213693649231,
#   'sorted_rank': 40,
#   'nation': 'United States'},
#  'Nicky Degrendele': {'rank': 21,
#   'gap': 0.22918786898350163,
#   'sorted_rank': 41,
#   'nation': 'Belgium'},
#  'Natalia Antonova': {'rank': 21,
#   'gap': 0.3427209813332084,
#   'sorted_rank': 42,
#   'nation': 'Russia'},
#  'Emma Cumming': {'rank': 22,
#   'gap': 0.3377787254054567,
#   'sorted_rank': 43,
#   'nation': 'New Zealand'},
#  'Marlena Karwacka': {'rank': 23,
#   'gap': 0.3465115461605919,
#   'sorted_rank': 44,
#   'nation': 'Poland'},
#  'Amelia Walsh': {'rank': 23,
#   'gap': 0.3398277819341615,
#   'sorted_rank': 45,
#   'nation': 'Canada'},
#  'Charlene du Preez': {'rank': 24,
#   'gap': 0.33802539894256256,
#   'sorted_rank': 46,
#   'nation': 'South Africa'},
#  'Guo Yufang': {'rank': 24,
#   'gap': 0.33877686338842494,
#   'sorted_rank': 47,
#   'nation': 'China'},
#  'Julita Jagodzińska': {'rank': 25,
#   'gap': 0.3401898195145634,
#   'sorted_rank': 48,
#   'nation': 'Poland'},
#  'Kayono Maeda': {'rank': 25,
#   'gap': 0.33898520491171524,
#   'sorted_rank': 49,
#   'nation': 'Japan'},
#  'Kim Won-gyeong': {'rank': 26,
#   'gap': 0.3179655742795049,
#   'sorted_rank': 50,
#   'nation': 'South Korea'},
#  'Yuli Verdugo': {'rank': 27,
#   'gap': 0.3330465242370906,
#   'sorted_rank': 51,
#   'nation': 'Mexico'},
#  'Robyn Stewart': {'rank': 27,
#   'gap': 0.10628987087402919,
#   'sorted_rank': 52,
#   'nation': 'Ireland'},
#  'Juliana Gaviria': {'rank': 27,
#   'gap': 0.33128680532664134,
#   'sorted_rank': 53,
#   'nation': 'Colombia'},
#  'Li Yin Yin': {'rank': 29,
#   'gap': 0.3315828187886254,
#   'sorted_rank': 54,
#   'nation': 'Hong Kong'},
#  'Helena Casas': {'rank': 30,
#   'gap': 0.3133913130833932,
#   'sorted_rank': 55,
#   'nation': 'Spain'},
#  'Deborah Herold': {'rank': 31,
#   'gap': 0.3118978696507426,
#   'sorted_rank': 56,
#   'nation': 'India'},
#  'Ma Wing Yu': {'rank': 35,
#   'gap': 0.1445263728487518,
#   'sorted_rank': 57,
#   'nation': 'Hong Kong'}}

# %%
json.dump(fix_results,open('women_sprint_results.json','w'), indent=2)
