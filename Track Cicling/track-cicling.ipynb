# %%
import json
import numpy as np
#from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sprint_individual_tournament import Cyclist, Tournament
from functools import partial
# %matplotlib inline

# %%
data = json.load(open('./data/men_sprint.json',encoding="utf-8"))
del data['Bronze medal final']
del data['Bronze medal race']
del data['Gold medal final']
del data['Gold medal race']

# %%
gaps = []
behinds = []
ciclysts = {}
times = []
for name,info in data.items():
    ciclysts[name]={
        'name': name,
        'nation': None,
        'years': [],
        'qualifying': {
            'times': [],
            'behinds': []
        },
        'rounds': {
            'gaps': []
        }
    }
    for year,yinfo in sorted(info.items(), key=lambda x: x[0]):
        ciclysts[name]['years'].append(int(year))
        for rinfo in yinfo.values():
            if ciclysts[name]['nation'] is None:
                ciclysts[name]['nation'] = rinfo['Nation']
            if rinfo.get('Gap',None):
                try:
                    gap = float(rinfo.get('Gap'))
                    gaps.append(gap)
                    ciclysts[name]['rounds']['gaps'].append(gap)
                except ValueError:
                    if rinfo.get('Gap')=="X":
                        ciclysts[name]['rounds']['gaps'].append(0)

                if rinfo.get('Race 1'):
                    try:
                        gap = float(rinfo.get('Race 1'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 1')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)

                    try:
                        gap = float(rinfo.get('Race 2'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 2')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)
            else:
                if rinfo.get('Behind',None):
                    try:
                        behind = float(rinfo.get('Behind'))
                        behinds.append(behind)
                        ciclysts[name]['qualifying']['behinds'].append(behind)
                    except ValueError:
                        pass
                if rinfo.get('Time',None):
                    try:
                        time = float(rinfo.get('Time'))
                        times.append(time)
                        ciclysts[name]['qualifying']['times'].append(time)
                    except ValueError:
                        pass

# %%
gaps_m = np.array(list(sorted(gaps))).mean()
behinds_m = np.array(list(sorted(behinds))).mean()
times_m = np.array(list(sorted(times))).mean()

# %%
for name in ciclysts.keys():
    mu = np.array(ciclysts[name]['qualifying']['times']).mean()
    if len(ciclysts[name]['qualifying']['times'])==1:
        variance =(behinds_m +np.array(ciclysts[name]['qualifying']['behinds']).mean())/2
    else:
        variance = np.abs(np.diff(np.array(ciclysts[name]['qualifying']['times']))).mean()
    sigma = math.sqrt(variance)
    ciclysts[name]['qualifying']['mean']=mu
    ciclysts[name]['qualifying']['std']=sigma

    mu = times_m
    if len(ciclysts[name]['rounds']['gaps'])==0:
        variance = 3/2*gaps_m
    else:
        variance = np.array(ciclysts[name]['rounds']['gaps']).mean()
        if len(ciclysts[name]['rounds']['gaps'])==1:
            variance = (4/3*gaps_m + variance)/2

    sigma = math.sqrt(variance)
    ciclysts[name]['rounds']['mean']=mu
    ciclysts[name]['rounds']['std']=sigma

# %%
# generate cyclist time function asumming normal distribution
cyclists_i = []
for i in ciclysts.values():
    qualify_time_function = partial(stats.norm.rvs,i['qualifying']['mean'],i['qualifying']['std'])
    round_time_fuction = partial(stats.norm.rvs,i['rounds']['mean'],i['rounds']['std'])
    name = i['name']
    nation = i['nation']
    cyclist = Cyclist(qualify_time_function, round_time_fuction, name, nation)
    cyclists_i.append(cyclist)

# %%
tournament = Tournament(cyclists_i)

# %%
results = {i.name:[] for i in cyclists_i}
nit = 1000

# %%
# run nit tournaments and save results
for i in range(nit):
    tournament.run()
    res = list(map(lambda x: x.name,tournament.winners))
    tournament.reset()
    for n,name in enumerate(res):
        results[name].append(n)

# %%
confidences = {}

for name, places in results.items():
    mean = np.mean(places)
    interval = stats.t.interval(0.95, len(places)-1, loc=mean, scale=stats.sem(places))
    confidences[name]= {
        'mean':mean,
        'interval': interval,
        'gap': mean-interval[0]
    }

# %%
sorted_cyclists = list(sorted(confidences.items(),key=lambda x: x[1]['mean']))

# %%
fix_results = {}
min_rank = math.floor(sorted_cyclists[0][1]['mean'])
for n,(name, data) in enumerate(sorted_cyclists):
    rank = int(math.floor(data['mean'])-min_rank) + 1
    fix_results[name] = {
        'rank': rank,
        'gap': data['gap'],
        'sorted_rank': n
    }

# %%
fix_results
# Out:
# {'Mateusz Rudyk': {'rank': 1, 'gap': 0.9732886818481816, 'sorted_rank': 0},
#  'Jeffrey Hoogland': {'rank': 2, 'gap': 0.9796005359945283, 'sorted_rank': 1},
#  'Sebastien Vigier': {'rank': 3, 'gap': 0.831412012637788, 'sorted_rank': 2},
#  'Denis Dmitriev': {'rank': 3, 'gap': 1.0144518328416936, 'sorted_rank': 3},
#  'Harrie Lavreysen': {'rank': 3, 'gap': 1.026535942422825, 'sorted_rank': 4},
#  'Jason Kenny': {'rank': 5, 'gap': 1.150750355781966, 'sorted_rank': 5},
#  'Nathan Hart': {'rank': 5, 'gap': 1.0076400159105212, 'sorted_rank': 6},
#  'Jack Carlin': {'rank': 6, 'gap': 0.9601108485864174, 'sorted_rank': 7},
#  'Nicholas Paul': {'rank': 6, 'gap': 1.1291561104906336, 'sorted_rank': 8},
#  'Max Niederlag': {'rank': 6, 'gap': 1.100760396211811, 'sorted_rank': 9},
#  'Yudai Nitta': {'rank': 6, 'gap': 1.198608692874295, 'sorted_rank': 10},
#  'Matthew Glaetzer': {'rank': 6, 'gap': 1.0031928289238436, 'sorted_rank': 11},
#  'Matthew Richardson': {'rank': 6,
#   'gap': 1.2611909465501157,
#   'sorted_rank': 12},
#  'Stefan Bötticher': {'rank': 7, 'gap': 1.1071089062085768, 'sorted_rank': 13},
#  'Quentin Caleyron': {'rank': 7, 'gap': 1.220635308680798, 'sorted_rank': 14},
#  'Zhou Yu': {'rank': 7, 'gap': 1.2875756122146917, 'sorted_rank': 15},
#  'Matthijs Büchli': {'rank': 8, 'gap': 1.2310237279077612, 'sorted_rank': 16},
#  'Sam Ligtlee': {'rank': 9, 'gap': 1.3198637331492016, 'sorted_rank': 17},
#  'Sándor Szalontay': {'rank': 10,
#   'gap': 1.1983330127699041,
#   'sorted_rank': 18},
#  'Ethan Mitchell': {'rank': 11, 'gap': 1.0460608850253017, 'sorted_rank': 19},
#  'Joseph Truman': {'rank': 11, 'gap': 1.2674839037550392, 'sorted_rank': 20},
#  'Tomohiro Fukaya': {'rank': 11, 'gap': 1.280838626974969, 'sorted_rank': 21},
#  'Melvin Landerneau': {'rank': 11,
#   'gap': 1.236753350501889,
#   'sorted_rank': 22},
#  'Ryan Owens': {'rank': 11, 'gap': 1.0530690784981793, 'sorted_rank': 23},
#  'Hsieh Nien-hsing': {'rank': 12,
#   'gap': 1.3569214546785382,
#   'sorted_rank': 24},
#  'Stefan Ritter': {'rank': 12, 'gap': 1.268309593245231, 'sorted_rank': 25},
#  'Sam Webster': {'rank': 12, 'gap': 1.2195602113086217, 'sorted_rank': 26},
#  'Vasilijus Lendel': {'rank': 13, 'gap': 1.235591445046083, 'sorted_rank': 27},
#  'Kevin Quintero': {'rank': 13, 'gap': 1.304987089740603, 'sorted_rank': 28},
#  'Njisane Phillip': {'rank': 13, 'gap': 1.2994561970204401, 'sorted_rank': 29},
#  'Xu Chao': {'rank': 14, 'gap': 1.1675051915723245, 'sorted_rank': 30},
#  'Hugo Barrette': {'rank': 14, 'gap': 0.8852309402213976, 'sorted_rank': 31},
#  'Martin Čechman': {'rank': 14, 'gap': 1.138364619490254, 'sorted_rank': 32},
#  'Pavel Kelemen': {'rank': 14, 'gap': 1.0865857830366181, 'sorted_rank': 33},
#  'Law Tsz Chun': {'rank': 15, 'gap': 1.409223125132506, 'sorted_rank': 34},
#  'Rayan Helal': {'rank': 15, 'gap': 1.3173898689800438, 'sorted_rank': 35},
#  'Muhammad Shah Firdaus Sahrom': {'rank': 15,
#   'gap': 1.4116711433496008,
#   'sorted_rank': 36},
#  'Kamil Kuczyński': {'rank': 15, 'gap': 1.3267773134374252, 'sorted_rank': 37},
#  'Maximilian Levy': {'rank': 16, 'gap': 1.333357984445577, 'sorted_rank': 38},
#  'Maximilian Dörnbach': {'rank': 16,
#   'gap': 1.3740364061053967,
#   'sorted_rank': 39},
#  'Fabián Puerta': {'rank': 16, 'gap': 1.1086168827242773, 'sorted_rank': 40},
#  'Eddie Dawkins': {'rank': 16, 'gap': 1.1684785474099826, 'sorted_rank': 41},
#  'Jair Tjon En Fa': {'rank': 16, 'gap': 1.2127637069483086, 'sorted_rank': 42},
#  'Pavel Yakushevskiy': {'rank': 17,
#   'gap': 0.3745843172184422,
#   'sorted_rank': 43},
#  'Azizulhasni Awang': {'rank': 17,
#   'gap': 1.2239006260771603,
#   'sorted_rank': 44},
#  'Callum Skinner': {'rank': 17, 'gap': 1.3649105616949981, 'sorted_rank': 45},
#  'Juan Peralta': {'rank': 17, 'gap': 1.2054283878713505, 'sorted_rank': 46},
#  'François Pervis': {'rank': 18, 'gap': 1.3730250737125473, 'sorted_rank': 47},
#  'Damian Zieliński': {'rank': 18,
#   'gap': 1.3569590042624284,
#   'sorted_rank': 48},
#  'Andriy Vynokurov': {'rank': 18,
#   'gap': 1.2154376011259984,
#   'sorted_rank': 49},
#  'Yuta Wakimoto': {'rank': 19, 'gap': 0.4520916033890785, 'sorted_rank': 50},
#  'Kazunari Watanabe': {'rank': 19,
#   'gap': 1.3191098508880756,
#   'sorted_rank': 51},
#  'Rafał Sarnecki': {'rank': 19, 'gap': 1.3618051547905452, 'sorted_rank': 52},
#  'Patrick Constable': {'rank': 20,
#   'gap': 1.3623750135371324,
#   'sorted_rank': 53},
#  'Im Chae-bin': {'rank': 20, 'gap': 1.3722403086433062, 'sorted_rank': 54},
#  'Joel Archambault': {'rank': 20, 'gap': 1.403544577516719, 'sorted_rank': 55},
#  'Santiago Ramírez': {'rank': 21,
#   'gap': 1.1799393100898712,
#   'sorted_rank': 56},
#  'Theo Bos': {'rank': 22, 'gap': 1.374978137440415, 'sorted_rank': 57},
#  'Tomoyuki Kawabata': {'rank': 22,
#   'gap': 1.1980844029302133,
#   'sorted_rank': 58},
#  'Muhammad Fadhil Mohd Zonis': {'rank': 22,
#   'gap': 1.2997195938493604,
#   'sorted_rank': 59},
#  'Nikita Shurshin': {'rank': 22, 'gap': 1.3405334319564233, 'sorted_rank': 60},
#  'Sandor Szalontay': {'rank': 23, 'gap': 1.337783232106844, 'sorted_rank': 61},
#  'Kirill Samusenko': {'rank': 24,
#   'gap': 1.3582980201395927,
#   'sorted_rank': 62},
#  'Maxim Nalyotov': {'rank': 24, 'gap': 1.4558785272288688, 'sorted_rank': 63},
#  'Eric Engler': {'rank': 24, 'gap': 0.6261457037684437, 'sorted_rank': 64},
#  'Muhammad Sahrom': {'rank': 26, 'gap': 1.4188748970885143, 'sorted_rank': 65},
#  'Svajūnas Jonauskas': {'rank': 27,
#   'gap': 1.3350993166090106,
#   'sorted_rank': 66},
#  'David Sojka': {'rank': 29, 'gap': 0.7018217764201893, 'sorted_rank': 67},
#  'Diego Peña': {'rank': 31, 'gap': 1.344025726534845, 'sorted_rank': 68},
#  'Kwesi Browne': {'rank': 31, 'gap': 1.3348682563676633, 'sorted_rank': 69},
#  'Jean Spies': {'rank': 32, 'gap': 0.23768430897450799, 'sorted_rank': 70},
#  'Sotirios Bretas': {'rank': 32, 'gap': 1.291941331282544, 'sorted_rank': 71}}
