# %%
import json
import numpy as np
#from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sprint_individual_tournament import Cyclist, Tournament
from functools import partial
# %matplotlib inline

# %%
data = json.load(open('./data/men_sprint.json',encoding="utf-8"))
del data['Bronze medal final']
del data['Bronze medal race']
del data['Gold medal final']
del data['Gold medal race']

# %%
gaps = []
behinds = []
ciclysts = {}
times = []
for name,info in data.items():
    ciclysts[name]={
        'name': name,
        'nation': None,
        'years': [],
        'qualifying': {
            'times': [],
            'behinds': []
        },
        'rounds': {
            'gaps': []
        }
    }
    for year,yinfo in sorted(info.items(), key=lambda x: x[0]):
        ciclysts[name]['years'].append(int(year))
        for rinfo in yinfo.values():
            if ciclysts[name]['nation'] is None:
                ciclysts[name]['nation'] = rinfo['Nation']
            if rinfo.get('Gap',None):
                try:
                    gap = float(rinfo.get('Gap'))
                    gaps.append(gap)
                    ciclysts[name]['rounds']['gaps'].append(gap)
                except ValueError:
                    if rinfo.get('Gap')=="X":
                        ciclysts[name]['rounds']['gaps'].append(0)

                if rinfo.get('Race 1'):
                    try:
                        gap = float(rinfo.get('Race 1'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 1')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)

                    try:
                        gap = float(rinfo.get('Race 2'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 2')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)
            else:
                if rinfo.get('Behind',None):
                    try:
                        behind = float(rinfo.get('Behind'))
                        behinds.append(behind)
                        ciclysts[name]['qualifying']['behinds'].append(behind)
                    except ValueError:
                        pass
                if rinfo.get('Time',None):
                    try:
                        time = float(rinfo.get('Time'))
                        times.append(time)
                        ciclysts[name]['qualifying']['times'].append(time)
                    except ValueError:
                        pass

# %%
gaps_m = np.array(list(sorted(gaps))).mean()
behinds_m = np.array(list(sorted(behinds))).mean()
times_m = np.array(list(sorted(times))).mean()

# %%
for name in ciclysts.keys():
    mu = np.array(ciclysts[name]['qualifying']['times']).mean()
    if len(ciclysts[name]['qualifying']['times'])==1:
        variance =(behinds_m +np.array(ciclysts[name]['qualifying']['behinds']).mean())/2
    else:
        variance = np.abs(np.diff(np.array(ciclysts[name]['qualifying']['times']))).mean()
    sigma = math.sqrt(variance)
    ciclysts[name]['qualifying']['mean']=mu
    ciclysts[name]['qualifying']['std']=sigma

    mu = times_m
    if len(ciclysts[name]['rounds']['gaps'])==0:
        variance = 3/2*gaps_m
    else:
        variance = np.array(ciclysts[name]['rounds']['gaps']).mean()
        if len(ciclysts[name]['rounds']['gaps'])==1:
            variance = (4/3*gaps_m + variance)/2

    sigma = math.sqrt(variance)
    ciclysts[name]['rounds']['mean']=mu
    ciclysts[name]['rounds']['std']=sigma

# %%
# generate cyclist time function asumming normal distribution
cyclists_i = []
for i in ciclysts.values():
    qualify_time_function = partial(stats.norm.rvs,i['qualifying']['mean'],i['qualifying']['std'])
    round_time_fuction = partial(stats.norm.rvs,i['rounds']['mean'],i['rounds']['std'])
    name = i['name']
    nation = i['nation']
    cyclist = Cyclist(qualify_time_function, round_time_fuction, name, nation)
    cyclists_i.append(cyclist)

# %%
tournament = Tournament(cyclists_i)

# %%
results = {i.name:[] for i in cyclists_i}
nit = 10000

# %%
# run nit tournaments and save results
for i in range(nit):
    tournament.run()
    res = list(map(lambda x: x.name,tournament.winners))
    tournament.reset()
    for n,name in enumerate(res):
        results[name].append(n)

# %%
nations = {i.name:i.nation for i in cyclists_i}

# %%
confidences = {}

for name, places in results.items():
    mean = np.mean(places)
    interval = stats.t.interval(0.95, len(places)-1, loc=mean, scale=stats.sem(places))
    confidences[name]= {
        'mean':mean,
        'interval': interval,
        'gap': mean-interval[0]
    }

# %%
sorted_cyclists = list(sorted(confidences.items(),key=lambda x: x[1]['mean']))

# %%
fix_results = {}
min_rank = math.floor(sorted_cyclists[0][1]['mean'])
for n,(name, data) in enumerate(sorted_cyclists):
    rank = int(math.floor(data['mean'])-min_rank) + 1
    fix_results[name] = {
        'rank': rank,
        'gap': data['gap'],
        'sorted_rank': n,
        'nation': nations[name]
    }

# %%
fix_results
# Out:
# {'Jeffrey Hoogland': {'rank': 1,
#   'gap': 0.30854753288612713,
#   'sorted_rank': 0,
#   'nation': 'Netherlands'},
#  'Mateusz Rudyk': {'rank': 2,
#   'gap': 0.31194211134726046,
#   'sorted_rank': 1,
#   'nation': 'Poland'},
#  'Sebastien Vigier': {'rank': 3,
#   'gap': 0.26001076474936724,
#   'sorted_rank': 2,
#   'nation': 'France'},
#  'Denis Dmitriev': {'rank': 4,
#   'gap': 0.31782289988093737,
#   'sorted_rank': 3,
#   'nation': 'Russia'},
#  'Harrie Lavreysen': {'rank': 4,
#   'gap': 0.3367541319566847,
#   'sorted_rank': 4,
#   'nation': 'Netherlands'},
#  'Nathan Hart': {'rank': 4,
#   'gap': 0.31873929597244555,
#   'sorted_rank': 5,
#   'nation': 'Australia'},
#  'Jason Kenny': {'rank': 5,
#   'gap': 0.37199561919499047,
#   'sorted_rank': 6,
#   'nation': 'Great Britain'},
#  'Yudai Nitta': {'rank': 5,
#   'gap': 0.371247959588338,
#   'sorted_rank': 7,
#   'nation': 'Japan'},
#  'Max Niederlag': {'rank': 5,
#   'gap': 0.3533861118429016,
#   'sorted_rank': 8,
#   'nation': 'Germany'},
#  'Matthew Glaetzer': {'rank': 6,
#   'gap': 0.307400384198953,
#   'sorted_rank': 9,
#   'nation': 'Australia'},
#  'Jack Carlin': {'rank': 6,
#   'gap': 0.31213870996878157,
#   'sorted_rank': 10,
#   'nation': 'Great Britain'},
#  'Nicholas Paul': {'rank': 6,
#   'gap': 0.35251348450900366,
#   'sorted_rank': 11,
#   'nation': 'Trinidad and Tobago'},
#  'Stefan Bötticher': {'rank': 6,
#   'gap': 0.34954527034792804,
#   'sorted_rank': 12,
#   'nation': 'Germany'},
#  'Matthew Richardson': {'rank': 7,
#   'gap': 0.39981858671765735,
#   'sorted_rank': 13,
#   'nation': 'Australia'},
#  'Quentin Caleyron': {'rank': 8,
#   'gap': 0.3893075428278543,
#   'sorted_rank': 14,
#   'nation': 'France'},
#  'Zhou Yu': {'rank': 8,
#   'gap': 0.41005191565024646,
#   'sorted_rank': 15,
#   'nation': 'China'},
#  'Matthijs Büchli': {'rank': 9,
#   'gap': 0.3904273325493435,
#   'sorted_rank': 16,
#   'nation': 'Netherlands'},
#  'Sándor Szalontay': {'rank': 9,
#   'gap': 0.37601632286089526,
#   'sorted_rank': 17,
#   'nation': 'Hungary'},
#  'Sam Ligtlee': {'rank': 10,
#   'gap': 0.41953394036881875,
#   'sorted_rank': 18,
#   'nation': 'Netherlands'},
#  'Ethan Mitchell': {'rank': 10,
#   'gap': 0.3299627448601363,
#   'sorted_rank': 19,
#   'nation': 'New Zealand'},
#  'Joseph Truman': {'rank': 10,
#   'gap': 0.40105184208150746,
#   'sorted_rank': 20,
#   'nation': 'Great Britain'},
#  'Ryan Owens': {'rank': 10,
#   'gap': 0.3416134665606023,
#   'sorted_rank': 21,
#   'nation': 'Great Britain'},
#  'Melvin Landerneau': {'rank': 11,
#   'gap': 0.3887088736361619,
#   'sorted_rank': 22,
#   'nation': 'France'},
#  'Tomohiro Fukaya': {'rank': 11,
#   'gap': 0.40699176831044426,
#   'sorted_rank': 23,
#   'nation': 'Japan'},
#  'Hsieh Nien-hsing': {'rank': 12,
#   'gap': 0.43342007716902486,
#   'sorted_rank': 24,
#   'nation': 'Chinese Taipei'},
#  'Sam Webster': {'rank': 12,
#   'gap': 0.377633507764493,
#   'sorted_rank': 25,
#   'nation': 'New Zealand'},
#  'Stefan Ritter': {'rank': 12,
#   'gap': 0.39885292529673677,
#   'sorted_rank': 26,
#   'nation': 'Canada'},
#  'Njisane Phillip': {'rank': 13,
#   'gap': 0.4152923717229058,
#   'sorted_rank': 27,
#   'nation': 'Trinidad and Tobago'},
#  'Law Tsz Chun': {'rank': 13,
#   'gap': 0.4386149025097552,
#   'sorted_rank': 28,
#   'nation': 'Hong Kong'},
#  'Kevin Quintero': {'rank': 13,
#   'gap': 0.4176416005243766,
#   'sorted_rank': 29,
#   'nation': 'Colombia'},
#  'Pavel Kelemen': {'rank': 14,
#   'gap': 0.34099751642384746,
#   'sorted_rank': 30,
#   'nation': 'Czech Republic'},
#  'Xu Chao': {'rank': 14,
#   'gap': 0.36331712490619594,
#   'sorted_rank': 31,
#   'nation': 'China'},
#  'Vasilijus Lendel': {'rank': 14,
#   'gap': 0.388172216816848,
#   'sorted_rank': 32,
#   'nation': 'Lithuania'},
#  'Martin Čechman': {'rank': 14,
#   'gap': 0.3542062844723972,
#   'sorted_rank': 33,
#   'nation': 'Czech Republic'},
#  'Rayan Helal': {'rank': 15,
#   'gap': 0.41378995366872573,
#   'sorted_rank': 34,
#   'nation': 'France'},
#  'Hugo Barrette': {'rank': 15,
#   'gap': 0.2742816560585979,
#   'sorted_rank': 35,
#   'nation': 'Canada'},
#  'Muhammad Shah Firdaus Sahrom': {'rank': 15,
#   'gap': 0.4422247120840197,
#   'sorted_rank': 36,
#   'nation': 'Malaysia'},
#  'Jair Tjon En Fa': {'rank': 15,
#   'gap': 0.38523388001859615,
#   'sorted_rank': 37,
#   'nation': 'Suriname'},
#  'Fabián Puerta': {'rank': 15,
#   'gap': 0.3571023320626807,
#   'sorted_rank': 38,
#   'nation': 'Colombia'},
#  'Eddie Dawkins': {'rank': 16,
#   'gap': 0.3700064359338384,
#   'sorted_rank': 39,
#   'nation': 'New Zealand'},
#  'Kamil Kuczyński': {'rank': 16,
#   'gap': 0.4201815243643594,
#   'sorted_rank': 40,
#   'nation': 'Poland'},
#  'Maximilian Levy': {'rank': 16,
#   'gap': 0.42061314063269606,
#   'sorted_rank': 41,
#   'nation': 'Germany'},
#  'Maximilian Dörnbach': {'rank': 16,
#   'gap': 0.4305080055878818,
#   'sorted_rank': 42,
#   'nation': 'Germany'},
#  'Pavel Yakushevskiy': {'rank': 17,
#   'gap': 0.11297511910208158,
#   'sorted_rank': 43,
#   'nation': 'Russia'},
#  'Azizulhasni Awang': {'rank': 17,
#   'gap': 0.381274326713239,
#   'sorted_rank': 44,
#   'nation': 'Malaysia'},
#  'François Pervis': {'rank': 17,
#   'gap': 0.4322458737570969,
#   'sorted_rank': 45,
#   'nation': 'France'},
#  'Juan Peralta': {'rank': 17,
#   'gap': 0.3729714611463848,
#   'sorted_rank': 46,
#   'nation': 'Spain'},
#  'Kazunari Watanabe': {'rank': 17,
#   'gap': 0.4224937543712244,
#   'sorted_rank': 47,
#   'nation': 'Japan'},
#  'Callum Skinner': {'rank': 18,
#   'gap': 0.42656226398482033,
#   'sorted_rank': 48,
#   'nation': 'Great Britain'},
#  'Damian Zieliński': {'rank': 18,
#   'gap': 0.42314327266378626,
#   'sorted_rank': 49,
#   'nation': 'Poland'},
#  'Patrick Constable': {'rank': 18,
#   'gap': 0.4271848682046695,
#   'sorted_rank': 50,
#   'nation': 'Australia'},
#  'Andriy Vynokurov': {'rank': 18,
#   'gap': 0.4002545466172691,
#   'sorted_rank': 51,
#   'nation': 'Ukraine'},
#  'Yuta Wakimoto': {'rank': 19,
#   'gap': 0.1406360425536164,
#   'sorted_rank': 52,
#   'nation': 'Japan'},
#  'Rafał Sarnecki': {'rank': 19,
#   'gap': 0.42966913919812555,
#   'sorted_rank': 53,
#   'nation': 'Poland'},
#  'Joel Archambault': {'rank': 20,
#   'gap': 0.4381924624191029,
#   'sorted_rank': 54,
#   'nation': 'Canada'},
#  'Santiago Ramírez': {'rank': 20,
#   'gap': 0.3727231476854769,
#   'sorted_rank': 55,
#   'nation': 'Colombia'},
#  'Im Chae-bin': {'rank': 20,
#   'gap': 0.42936161307163445,
#   'sorted_rank': 56,
#   'nation': 'South Korea'},
#  'Theo Bos': {'rank': 21,
#   'gap': 0.43474493274765535,
#   'sorted_rank': 57,
#   'nation': 'Netherlands'},
#  'Nikita Shurshin': {'rank': 21,
#   'gap': 0.42870582560106385,
#   'sorted_rank': 58,
#   'nation': 'Russia'},
#  'Tomoyuki Kawabata': {'rank': 22,
#   'gap': 0.3792249540324093,
#   'sorted_rank': 59,
#   'nation': 'Japan'},
#  'Sandor Szalontay': {'rank': 22,
#   'gap': 0.4357005938953975,
#   'sorted_rank': 60,
#   'nation': 'Hungary'},
#  'Muhammad Fadhil Mohd Zonis': {'rank': 22,
#   'gap': 0.4138635408109437,
#   'sorted_rank': 61,
#   'nation': 'Malaysia'},
#  'Kirill Samusenko': {'rank': 23,
#   'gap': 0.4344243438340243,
#   'sorted_rank': 62,
#   'nation': 'Russia'},
#  'Eric Engler': {'rank': 25,
#   'gap': 0.18855313626998083,
#   'sorted_rank': 63,
#   'nation': 'Germany'},
#  'Maxim Nalyotov': {'rank': 25,
#   'gap': 0.4412983109237274,
#   'sorted_rank': 64,
#   'nation': 'Kazakhstan'},
#  'Svajūnas Jonauskas': {'rank': 26,
#   'gap': 0.43461756181694966,
#   'sorted_rank': 65,
#   'nation': 'Lithuania'},
#  'Muhammad Sahrom': {'rank': 28,
#   'gap': 0.427069783869527,
#   'sorted_rank': 66,
#   'nation': 'Malaysia'},
#  'David Sojka': {'rank': 30,
#   'gap': 0.2061973223159228,
#   'sorted_rank': 67,
#   'nation': 'Czech Republic'},
#  'Diego Peña': {'rank': 31,
#   'gap': 0.4183588012254802,
#   'sorted_rank': 68,
#   'nation': 'Colombia'},
#  'Kwesi Browne': {'rank': 31,
#   'gap': 0.41618841481992774,
#   'sorted_rank': 69,
#   'nation': 'Trinidad and Tobago'},
#  'Jean Spies': {'rank': 32,
#   'gap': 0.07331126391575538,
#   'sorted_rank': 70,
#   'nation': 'South Africa'},
#  'Sotirios Bretas': {'rank': 33,
#   'gap': 0.4079914685491417,
#   'sorted_rank': 71,
#   'nation': 'Greece'}}

# %%
json.dump(fix_results,open('men_sprint_results.json','w'), indent=2)
