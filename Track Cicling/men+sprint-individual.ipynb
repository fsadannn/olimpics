# %%
import json
import numpy as np
#from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sprint_individual_tournament import Cyclist, Tournament
from functools import partial
# %matplotlib inline

# %%
data = json.load(open('./data/men_sprint.json',encoding="utf-8"))
del data['Bronze medal final']
del data['Bronze medal race']
del data['Gold medal final']
del data['Gold medal race']

# %%
gaps = []
behinds = []
ciclysts = {}
times = []
for name,info in data.items():
    ciclysts[name]={
        'name': name,
        'nation': None,
        'years': [],
        'qualifying': {
            'times': [],
            'behinds': []
        },
        'rounds': {
            'gaps': []
        }
    }
    for year,yinfo in sorted(info.items(), key=lambda x: x[0]):
        ciclysts[name]['years'].append(int(year))
        for rinfo in yinfo.values():
            if ciclysts[name]['nation'] is None:
                ciclysts[name]['nation'] = rinfo['Nation']
            if rinfo.get('Gap',None):
                try:
                    gap = float(rinfo.get('Gap'))
                    gaps.append(gap)
                    ciclysts[name]['rounds']['gaps'].append(gap)
                except ValueError:
                    if rinfo.get('Gap')=="X":
                        ciclysts[name]['rounds']['gaps'].append(0)

                if rinfo.get('Race 1'):
                    try:
                        gap = float(rinfo.get('Race 1'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 1')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)

                    try:
                        gap = float(rinfo.get('Race 2'))
                        gaps.append(gap)
                        ciclysts[name]['rounds']['gaps'].append(gap)
                    except ValueError:
                        if rinfo.get('Race 2')=="X":
                            ciclysts[name]['rounds']['gaps'].append(0)
            else:
                if rinfo.get('Behind',None):
                    try:
                        behind = float(rinfo.get('Behind'))
                        behinds.append(behind)
                        ciclysts[name]['qualifying']['behinds'].append(behind)
                    except ValueError:
                        pass
                if rinfo.get('Time',None):
                    try:
                        time = float(rinfo.get('Time'))
                        times.append(time)
                        ciclysts[name]['qualifying']['times'].append(time)
                    except ValueError:
                        pass

# %%
gaps_m = np.array(list(sorted(gaps))).mean()
behinds_m = np.array(list(sorted(behinds))).mean()
times_m = np.array(list(sorted(times))).mean()

# %%
for name in ciclysts.keys():
    mu = np.array(ciclysts[name]['qualifying']['times']).mean()
    if len(ciclysts[name]['qualifying']['times'])==1:
        variance =(behinds_m +np.array(ciclysts[name]['qualifying']['behinds']).mean())/2
    else:
        variance = np.abs(np.diff(np.array(ciclysts[name]['qualifying']['times']))).mean()
    sigma = math.sqrt(variance)
    ciclysts[name]['qualifying']['mean']=mu
    ciclysts[name]['qualifying']['std']=sigma

    mu = times_m
    if len(ciclysts[name]['rounds']['gaps'])==0:
        variance = 3/2*gaps_m
    else:
        variance = np.array(ciclysts[name]['rounds']['gaps']).mean()
        if len(ciclysts[name]['rounds']['gaps'])==1:
            variance = (4/3*gaps_m + variance)/2

    sigma = math.sqrt(variance)
    ciclysts[name]['rounds']['mean']=mu
    ciclysts[name]['rounds']['std']=sigma

# %%
# generate cyclist time function asumming normal distribution
cyclists_i = []
for i in ciclysts.values():
    qualify_time_function = partial(stats.norm.rvs,i['qualifying']['mean'],i['qualifying']['std'])
    round_time_fuction = partial(stats.norm.rvs,i['rounds']['mean'],i['rounds']['std'])
    name = i['name']
    nation = i['nation']
    cyclist = Cyclist(qualify_time_function, round_time_fuction, name, nation)
    cyclists_i.append(cyclist)

# %%
tournament = Tournament(cyclists_i)

# %%
results = {i.name:[] for i in cyclists_i}
nit = 10000

# %%
# run nit tournaments and save results
for i in range(nit):
    tournament.run()
    res = list(map(lambda x: x.name,tournament.winners))
    tournament.reset()
    for n,name in enumerate(res):
        results[name].append(n)

# %%
nations = {i.name:i.nation for i in cyclists_i}

# %%
confidences = {}

for name, places in results.items():
    mean = np.mean(places)
    interval = stats.t.interval(0.95, len(places)-1, loc=mean, scale=stats.sem(places))
    confidences[name]= {
        'mean':mean,
        'interval': interval,
        'gap': mean-interval[0]
    }

# %%
sorted_cyclists = list(sorted(confidences.items(),key=lambda x: x[1]['mean']))

# %%
fix_results = {}
min_rank = math.floor(sorted_cyclists[0][1]['mean'])
for n,(name, data) in enumerate(sorted_cyclists):
    rank = int(math.floor(data['mean'])-min_rank) + 1
    fix_results[name] = {
        'rank': rank,
        'gap': data['gap'],
        'sorted_rank': n,
        'nation': nations[name]
    }

# %%
fix_results
# Out:
# {'Jeffrey Hoogland': {'rank': 1,
#   'gap': 0.3063774995148947,
#   'sorted_rank': 0,
#   'nation': 'Netherlands'},
#  'Mateusz Rudyk': {'rank': 2,
#   'gap': 0.31482598037321097,
#   'sorted_rank': 1,
#   'nation': 'Poland'},
#  'Sebastien Vigier': {'rank': 3,
#   'gap': 0.2626736015216302,
#   'sorted_rank': 2,
#   'nation': 'France'},
#  'Denis Dmitriev': {'rank': 3,
#   'gap': 0.3149012413340344,
#   'sorted_rank': 3,
#   'nation': 'Russia'},
#  'Harrie Lavreysen': {'rank': 4,
#   'gap': 0.3354354649010496,
#   'sorted_rank': 4,
#   'nation': 'Netherlands'},
#  'Nathan Hart': {'rank': 4,
#   'gap': 0.3137359536937119,
#   'sorted_rank': 5,
#   'nation': 'Australia'},
#  'Yudai Nitta': {'rank': 5,
#   'gap': 0.36803824288062614,
#   'sorted_rank': 6,
#   'nation': 'Japan'},
#  'Jason Kenny': {'rank': 5,
#   'gap': 0.3710808346830987,
#   'sorted_rank': 7,
#   'nation': 'Great Britain'},
#  'Max Niederlag': {'rank': 5,
#   'gap': 0.3539692599194133,
#   'sorted_rank': 8,
#   'nation': 'Germany'},
#  'Matthew Glaetzer': {'rank': 6,
#   'gap': 0.30912666133277256,
#   'sorted_rank': 9,
#   'nation': 'Australia'},
#  'Nicholas Paul': {'rank': 6,
#   'gap': 0.35153811254158285,
#   'sorted_rank': 10,
#   'nation': 'Trinidad and Tobago'},
#  'Jack Carlin': {'rank': 6,
#   'gap': 0.31132946894865654,
#   'sorted_rank': 11,
#   'nation': 'Great Britain'},
#  'Stefan Bötticher': {'rank': 6,
#   'gap': 0.35310878142214364,
#   'sorted_rank': 12,
#   'nation': 'Germany'},
#  'Matthew Richardson': {'rank': 7,
#   'gap': 0.39813100534384205,
#   'sorted_rank': 13,
#   'nation': 'Australia'},
#  'Quentin Caleyron': {'rank': 8,
#   'gap': 0.3870189831589599,
#   'sorted_rank': 14,
#   'nation': 'France'},
#  'Matthijs Büchli': {'rank': 9,
#   'gap': 0.3910902492973065,
#   'sorted_rank': 15,
#   'nation': 'Netherlands'},
#  'Zhou Yu': {'rank': 9,
#   'gap': 0.415475448796343,
#   'sorted_rank': 16,
#   'nation': 'China'},
#  'Sándor Szalontay': {'rank': 10,
#   'gap': 0.375834427499683,
#   'sorted_rank': 17,
#   'nation': 'Hungary'},
#  'Ethan Mitchell': {'rank': 10,
#   'gap': 0.3297105531720348,
#   'sorted_rank': 18,
#   'nation': 'New Zealand'},
#  'Sam Ligtlee': {'rank': 10,
#   'gap': 0.4204252140539033,
#   'sorted_rank': 19,
#   'nation': 'Netherlands'},
#  'Joseph Truman': {'rank': 10,
#   'gap': 0.40095169047425117,
#   'sorted_rank': 20,
#   'nation': 'Great Britain'},
#  'Ryan Owens': {'rank': 10,
#   'gap': 0.3411154105354903,
#   'sorted_rank': 21,
#   'nation': 'Great Britain'},
#  'Tomohiro Fukaya': {'rank': 11,
#   'gap': 0.4066933078172319,
#   'sorted_rank': 22,
#   'nation': 'Japan'},
#  'Melvin Landerneau': {'rank': 11,
#   'gap': 0.3875160304813541,
#   'sorted_rank': 23,
#   'nation': 'France'},
#  'Hsieh Nien-hsing': {'rank': 12,
#   'gap': 0.43362783558727713,
#   'sorted_rank': 24,
#   'nation': 'Chinese Taipei'},
#  'Sam Webster': {'rank': 12,
#   'gap': 0.37711696815860307,
#   'sorted_rank': 25,
#   'nation': 'New Zealand'},
#  'Stefan Ritter': {'rank': 12,
#   'gap': 0.40203671232581684,
#   'sorted_rank': 26,
#   'nation': 'Canada'},
#  'Kevin Quintero': {'rank': 13,
#   'gap': 0.41521605231304193,
#   'sorted_rank': 27,
#   'nation': 'Colombia'},
#  'Njisane Phillip': {'rank': 13,
#   'gap': 0.41585359241494047,
#   'sorted_rank': 28,
#   'nation': 'Trinidad and Tobago'},
#  'Law Tsz Chun': {'rank': 13,
#   'gap': 0.4400422726524482,
#   'sorted_rank': 29,
#   'nation': 'Hong Kong'},
#  'Vasilijus Lendel': {'rank': 14,
#   'gap': 0.3871941726274173,
#   'sorted_rank': 30,
#   'nation': 'Lithuania'},
#  'Xu Chao': {'rank': 14,
#   'gap': 0.367643586847592,
#   'sorted_rank': 31,
#   'nation': 'China'},
#  'Pavel Kelemen': {'rank': 14,
#   'gap': 0.3429749013731751,
#   'sorted_rank': 32,
#   'nation': 'Czech Republic'},
#  'Martin Čechman': {'rank': 14,
#   'gap': 0.35336993185322996,
#   'sorted_rank': 33,
#   'nation': 'Czech Republic'},
#  'Muhammad Shah Firdaus Sahrom': {'rank': 15,
#   'gap': 0.447359523868883,
#   'sorted_rank': 34,
#   'nation': 'Malaysia'},
#  'Hugo Barrette': {'rank': 15,
#   'gap': 0.27526391277577744,
#   'sorted_rank': 35,
#   'nation': 'Canada'},
#  'Rayan Helal': {'rank': 15,
#   'gap': 0.41244347334033904,
#   'sorted_rank': 36,
#   'nation': 'France'},
#  'Kamil Kuczyński': {'rank': 15,
#   'gap': 0.4190732435346973,
#   'sorted_rank': 37,
#   'nation': 'Poland'},
#  'Fabián Puerta': {'rank': 15,
#   'gap': 0.36124087763035817,
#   'sorted_rank': 38,
#   'nation': 'Colombia'},
#  'Jair Tjon En Fa': {'rank': 16,
#   'gap': 0.3860382608413673,
#   'sorted_rank': 39,
#   'nation': 'Suriname'},
#  'Eddie Dawkins': {'rank': 16,
#   'gap': 0.37009776450135234,
#   'sorted_rank': 40,
#   'nation': 'New Zealand'},
#  'Maximilian Levy': {'rank': 16,
#   'gap': 0.4181881396296703,
#   'sorted_rank': 41,
#   'nation': 'Germany'},
#  'Maximilian Dörnbach': {'rank': 16,
#   'gap': 0.42805824674855586,
#   'sorted_rank': 42,
#   'nation': 'Germany'},
#  'Azizulhasni Awang': {'rank': 16,
#   'gap': 0.3815772497607952,
#   'sorted_rank': 43,
#   'nation': 'Malaysia'},
#  'Pavel Yakushevskiy': {'rank': 17,
#   'gap': 0.1124425565131375,
#   'sorted_rank': 44,
#   'nation': 'Russia'},
#  'Kazunari Watanabe': {'rank': 17,
#   'gap': 0.42167515521524024,
#   'sorted_rank': 45,
#   'nation': 'Japan'},
#  'François Pervis': {'rank': 17,
#   'gap': 0.430335830948799,
#   'sorted_rank': 46,
#   'nation': 'France'},
#  'Juan Peralta': {'rank': 18,
#   'gap': 0.36832148332167236,
#   'sorted_rank': 47,
#   'nation': 'Spain'},
#  'Damian Zieliński': {'rank': 18,
#   'gap': 0.42260299202663987,
#   'sorted_rank': 48,
#   'nation': 'Poland'},
#  'Patrick Constable': {'rank': 18,
#   'gap': 0.4343182911464396,
#   'sorted_rank': 49,
#   'nation': 'Australia'},
#  'Callum Skinner': {'rank': 18,
#   'gap': 0.42914098629037056,
#   'sorted_rank': 50,
#   'nation': 'Great Britain'},
#  'Andriy Vynokurov': {'rank': 18,
#   'gap': 0.4014149646261984,
#   'sorted_rank': 51,
#   'nation': 'Ukraine'},
#  'Yuta Wakimoto': {'rank': 19,
#   'gap': 0.14044484619826392,
#   'sorted_rank': 52,
#   'nation': 'Japan'},
#  'Rafał Sarnecki': {'rank': 19,
#   'gap': 0.4301311969360242,
#   'sorted_rank': 53,
#   'nation': 'Poland'},
#  'Joel Archambault': {'rank': 20,
#   'gap': 0.4409566203946511,
#   'sorted_rank': 54,
#   'nation': 'Canada'},
#  'Santiago Ramírez': {'rank': 20,
#   'gap': 0.37224544016100225,
#   'sorted_rank': 55,
#   'nation': 'Colombia'},
#  'Im Chae-bin': {'rank': 21,
#   'gap': 0.4282599323179852,
#   'sorted_rank': 56,
#   'nation': 'South Korea'},
#  'Theo Bos': {'rank': 21,
#   'gap': 0.43393405557596054,
#   'sorted_rank': 57,
#   'nation': 'Netherlands'},
#  'Nikita Shurshin': {'rank': 21,
#   'gap': 0.4312090993307578,
#   'sorted_rank': 58,
#   'nation': 'Russia'},
#  'Tomoyuki Kawabata': {'rank': 22,
#   'gap': 0.37749620832404673,
#   'sorted_rank': 59,
#   'nation': 'Japan'},
#  'Sandor Szalontay': {'rank': 22,
#   'gap': 0.4326885168725312,
#   'sorted_rank': 60,
#   'nation': 'Hungary'},
#  'Muhammad Fadhil Mohd Zonis': {'rank': 23,
#   'gap': 0.41303653594183487,
#   'sorted_rank': 61,
#   'nation': 'Malaysia'},
#  'Kirill Samusenko': {'rank': 24,
#   'gap': 0.4344800400118203,
#   'sorted_rank': 62,
#   'nation': 'Russia'},
#  'Eric Engler': {'rank': 25,
#   'gap': 0.18714222441953154,
#   'sorted_rank': 63,
#   'nation': 'Germany'},
#  'Maxim Nalyotov': {'rank': 25,
#   'gap': 0.43865274891445694,
#   'sorted_rank': 64,
#   'nation': 'Kazakhstan'},
#  'Svajūnas Jonauskas': {'rank': 27,
#   'gap': 0.42776506981518736,
#   'sorted_rank': 65,
#   'nation': 'Lithuania'},
#  'Muhammad Sahrom': {'rank': 28,
#   'gap': 0.4266452979225619,
#   'sorted_rank': 66,
#   'nation': 'Malaysia'},
#  'David Sojka': {'rank': 30,
#   'gap': 0.2067367347675244,
#   'sorted_rank': 67,
#   'nation': 'Czech Republic'},
#  'Diego Peña': {'rank': 31,
#   'gap': 0.4203802320104515,
#   'sorted_rank': 68,
#   'nation': 'Colombia'},
#  'Jean Spies': {'rank': 32,
#   'gap': 0.0732130259471262,
#   'sorted_rank': 69,
#   'nation': 'South Africa'},
#  'Kwesi Browne': {'rank': 32,
#   'gap': 0.41235915455352057,
#   'sorted_rank': 70,
#   'nation': 'Trinidad and Tobago'},
#  'Sotirios Bretas': {'rank': 32,
#   'gap': 0.41324062702489783,
#   'sorted_rank': 71,
#   'nation': 'Greece'}}

# %%
json.dump(fix_results,open('men_sprint_results.json','w'), indent=2)
